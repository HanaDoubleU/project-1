# %%
import pandas as pd
import numpy

data = pd.read_csv("SCFP2022.csv")
data.head(15)
# Out:
#     YY1  Y1          WGT  HHSEX  AGE  AGECL  EDUC  EDCL  MARRIED  KIDS  ...  \
# 0     1  11  3027.956120      2   70      5     9     3        2     2  ...
# 1     1  12  3054.900065      2   70      5     9     3        2     2  ...
# 2     1  13  3163.637766      2   70      5     9     3        2     2  ...
# 3     1  14  3166.228463      2   70      5     9     3        2     2  ...
# 4     1  15  3235.624715      2   70      5     9     3        2     2  ...
# 5     2  21   236.634754      1   46      3    12     4        2     0  ...
# 6     2  22   245.848398      1   46      3    12     4        2     0  ...
# 7     2  23   253.103477      1   46      3    12     4        2     0  ...
# 8     2  24   252.908118      1   46      3    12     4        2     0  ...
# 9     2  25   253.811312      1   46      3    12     4        2     0  ...
# 10    3  31   678.869307      1   68      5    14     4        1     0  ...
# ...

# %%
data_df = data[['YY1',
                'AGE', 
                'AGECL', 
                'EDCL', 
                'EDUC', 
                'FAMSTRUCT', 
                'KIDS', 
                'MARRIED', 
                'OCCAT1', 
                'OCCAT2', 
                'RACE', 
                'RACECL', 
                'RACECL4', 
                'LIFECL', 
                'LF', 
                'INDCAT', 
                'ASSET', 
                'EQUITY', 
                'HOMEEQ', 
                'RETEQ', 
                'ANYPEN', 
                'ACTBUS', 
                'NONACTBUS', 
                'IRAKH', 
                'ANNUIT', 
                'TRUSTS', 
                'EQUITINC', 
                'HBROK', 
                'PIRMORT', 
                'PIRTOTAL', 
                'DEBT2INC', 
                'KNOWL', 
                'SAVRES1', 
                'SAVRES2', 
                'SAVRES3', 
                'SAVRES4', 
                'SAVRES5', 
                'SAVRES6', 
                'SAVRES7', 
                'SAVRES8', 
                'SAVRES9', 
                'INCOME', 
                'INCCAT', 
                'INCPCTLECAT', 
                'SSRETINC', 
                'WAGEINC', 
                'NETWORTH'
               ]]
data_df
# Out:
#         YY1  AGE  AGECL  EDCL  EDUC  FAMSTRUCT  KIDS  MARRIED  OCCAT1  OCCAT2  \
# 0         1   70      5     3     9          1     2        2       3       4
# 1         1   70      5     3     9          1     2        2       3       4
# 2         1   70      5     3     9          1     2        2       3       4
# 3         1   70      5     3     9          1     2        2       3       4
# 4         1   70      5     3     9          1     2        2       3       4
# ...     ...  ...    ...   ...   ...        ...   ...      ...     ...     ...
# 22970  4603   40      2     2     8          1     2        2       3       4
# 22971  4603   40      2     2     8          1     2        2       3       4
# 22972  4603   40      2     2     8          1     2        2       3       4
# 22973  4603   40      2     2     8          1     2        2       3       4
# 22974  4603   40      2     2     8          1     2        2       3       4
#
# ...

# %%
data_df.to_csv('output.csv', index=True)
